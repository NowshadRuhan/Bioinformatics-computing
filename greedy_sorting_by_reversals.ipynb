# %%
import array 
import string


final = [1, 2, 3, 4, 5, 6]
arr1 = []
number = 6
count = 0


def revesal(i) :
    s = i
    e = number_of_match
    while s<=e:
        if(s == e):
            arr1[s]=(-1*arr1[s])
            break
        
        m = arr1[s]
        arr1[s] = arr1[e]
        arr1[s] = (-1*arr1[s])
        arr1[e] = m
        arr1[e] = (-1*arr1[e])
        
        s=s+1
        e = e-1
        
            


            
for i in range(number):
    n = int(input())
    arr1.append(n)
    
i=0
while i <number:
    number_of_match= 0
    if(abs(arr1[i])!=final[i]):
        count=count+1
        j=i+1
        while j<number :
            if(abs(arr1[j]) == final[i]):
                number_of_match = j         
                break   
            j=j+1
        
        revesal(i)
        print(arr1)
        
        if(arr1[i]<0):
            count=count+1
            arr1[i] = (-arr1[i])
            print(arr1)
            
        
    elif(arr1[i]<0):
        count=count+1
        arr1[i] = (-arr1[i])
        print(arr1)
    
    i=i+1
            
print(count)
            

#input:
#5
#-6
#1
#3
#-2
#-4
# Out:
# 5
# -6
# 1
# 3
# -2
# -4
# [-1, 6, -5, 3, -2, -4]
# [1, 6, -5, 3, -2, -4]
# [1, 2, -3, 5, -6, -4]
# [1, 2, 3, 5, -6, -4]
# [1, 2, 3, 4, 6, -5]
# [1, 2, 3, 4, 5, -6]
# [1, 2, 3, 4, 5, 6]
# 7
